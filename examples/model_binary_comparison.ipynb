# %%
# Compare the skill of the model forecast using the depth data at the resolution of the DEM.

# Library imports.
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import savemat
import os
import rasterio

# Local imports.
from rasopt.Utilities import utils, land_cover_utils

# %%
# Plan files to compare.
gt_plan_fp = r"C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf"
sim_best_plan_fp = r"C:\Users\ay434\Box\Research\Flood_Sim_Materials\BayesOpt_Paper\Data\Secchia_Panaro.p23_camp0.05_2veg_30min.hdf"
# sim_best_plan_fp = r"C:\Users\ay434\Box\Research\Flood_Sim_Materials\Presentations\EFMH_Presentation_20220316\Secchia_Panaro.p23_15min_campagna0.05.hdf";

# Path to the DEM file.
dem_fname = r"DTM_1m.tif"
dem_fp = os.path.join(os.path.dirname(gt_plan_fp), dem_fname)
dem_fp = r"C:\Users\ay434\Box\Research\Flood_Sim_Materials\Presentations\EFMH_Presentation_20220316\DTM_1m.tif"

# Comparison timestep.
timestep = 120
dt = 0.5 # Hours.

# Downsample factor.
resample = 0.05

# HDF paths.
# Cell coordinate path.
cell_coord_path = 'Geometry/2D Flow Areas/Secchia_Panaro/Cells Center Coordinate'

# Water depths path.
depth_path = ('Results/Unsteady/Output/Output Blocks/Base Output/Unsteady Time Series/'
              '2D Flow Areas/Secchia_Panaro/Depth')

# Manning's n calibration table path.
cal_table_path = "Geometry/Land Cover (Manning's n)/Calibration Table"

# Cell facepoint index path.
cell_facepoint_idx_path = 'Geometry/2D Flow Areas/Secchia_Panaro/Cells FacePoint Indexes'

# Facepoint coordinate path.
facepoint_coord_path = 'Geometry/2D Flow Areas/Secchia_Panaro/FacePoints Coordinate'

# %%
# Time step with greatest flood extent.
gt_mesh_depths = utils.extract_depths(gt_plan_fp, depth_path, cell_coord_path)
Nt = len(gt_mesh_depths.columns) - 2

n_inun = np.zeros(Nt)
for t in range(Nt):
    col_name = f'Time_{t}'
    mesh_inun = gt_mesh_depths.loc[gt_mesh_depths[col_name] > 0.01, :]
    n_inun[t] = mesh_inun.shape[0]

timestep = np.argmax(n_inun)
print(timestep)
# Out:
# 174

# %%
# Depth rasters at the resolution of the DEM raster.
gt_depths, gt_depth_path = land_cover_utils.terrain_water_depth(dem_fp, gt_plan_fp, cell_facepoint_idx_path, facepoint_coord_path,
                                        depth_path, cell_coord_path, timestep, out_fname_prefix='GT', nodata=-999.0, 
                                        cleanup_rasters=False, resample=resample)
sim_depths, sim_depth_path = land_cover_utils.terrain_water_depth(dem_fp, sim_best_plan_fp, cell_facepoint_idx_path, facepoint_coord_path,
                                        depth_path, cell_coord_path, timestep, out_fname_prefix='', nodata=-999.0,
                                        cleanup_rasters=False, resample=resample)


# Compute the sensitivity.
sensitivity = utils.inun_sensitivity(gt_depths, sim_depths, depth_cut=0.01)

# Type I and II Error.
typeI = utils.inun_error(gt_depths, sim_depths, 1, depth_cut=0.01)
typeII = utils.inun_error(gt_depths, sim_depths, 2, depth_cut=0.01)

# Fit.
fit = utils.inun_fit(gt_depths, sim_depths, depth_cut=0.01)

# Print results.
print('Sensitivity', sensitivity)
print('Type I', typeI)
print('Type II', typeII)
print('Fit', fit)
# Out:
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_174.tif
# (1335, 1521)
# C:\Users\ay434\Box\Research\Flood_Sim_Materials\BayesOpt_Paper\Data\Secchia_Panaro.p23_camp0.05_2veg_30min.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_174.tif
# (1335, 1521)
# Sensitivity 0.9389383883938939
# Type I 0.05613610530561361
# Type II 0.06598711790659871
# Fit 0.9343363090170514

# %%
# Get top left and bottom right coordinates.
with rasterio.open(r'C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_222.tif', 'r') as ds:
    print('TOP LEFT', ds.transform * (0, 0))
    print('BOTTOM RIGHT', ds.transform * (ds.width, ds.height))
# Out:
# TOP LEFT (652093.732276195, 4972124.219236948)
# BOTTOM RIGHT (682516.732276195, 4945405.219236948)

# %%
# Plot the mismatch.
out_path = r"C:\Users\ay434\Box\Research\Flood_Sim_Materials\BayesOpt_Paper\Data\1_veg"
suffix = '1veg_camp005'
gt_inun = gt_depths.copy()
gt_inun[gt_inun >= 0.01] = 1
gt_inun[gt_inun < 0.01] = 0
gt_bool = np.array(gt_inun, dtype=bool)
gt_inun[gt_inun == 0] = np.nan

sim_inun = sim_depths.copy()
sim_inun[sim_inun >= 0.01] = 1
sim_inun[sim_inun < 0.01] = 0
sim_bool = np.array(sim_inun, dtype=bool)
sim_inun[sim_inun == 0] = np.nan

gt_and_sim = np.logical_and(gt_bool, sim_bool).astype(float)
gt_and_sim[gt_and_sim == 0] = np.nan
savemat(os.path.join(out_path, f'gt_and_sim_{suffix}.mat'), {f'gt_and_sim': gt_and_sim})

gt_and_notsim = np.logical_and(gt_bool, ~sim_bool).astype(float)
gt_and_notsim[gt_and_notsim == 0] = np.nan
savemat(os.path.join(out_path, f'gt_and_notsim_{suffix}.mat'), {f'gt_and_notsim': gt_and_notsim})

notgt_and_sim = np.logical_and(~gt_bool, sim_bool).astype(float)
notgt_and_sim[notgt_and_sim == 0] = np.nan
savemat(os.path.join(out_path, f'notgt_and_sim_{suffix}.mat'), {f'notgt_and_sim': notgt_and_sim})

gt_or_sim = np.logical_or(gt_bool, sim_bool).astype(float)
gt_or_sim[gt_or_sim == 0] = np.nan
savemat(os.path.join(out_path, f'gt_or_sim_{suffix}.mat'), {f'gt_or_sim': gt_or_sim})

gt_xor_sim = np.logical_xor(gt_bool, sim_bool).astype(float)
gt_xor_sim[gt_xor_sim == 0] = np.nan
savemat(os.path.join(out_path, f'gt_xor_sim_{suffix}.mat'), {f'gt_xor_sim': gt_xor_sim})

fig, ax = plt.subplots(figsize=(40,40))
# ax.imshow(gt_inun, vmin=0, vmax=2)
# ax.imshow(sim_inun, vmin=1, vmax=2)
ax.imshow(gt_and_sim, cmap='Blues', vmin=0, vmax=2)
ax.imshow(gt_and_notsim, cmap='Reds', vmin=0, vmax=1)
ax.imshow(notgt_and_sim, cmap='Greens', vmin=0, vmax=1)
parameters = {'axes.labelsize': 25,
          'axes.titlesize': 35}
plt.rcParams.update(parameters)

# %%
# Get the total number of timesteps. 
depths = utils.extract_depths(gt_plan_fp, depth_path, cell_coord_path)
Nt = depths.shape[1] - 2
print(Nt)
# Out:
# 283

# %%
# Critical depth comparison.
depth_cut = 0.1

# Time to critical depth arrays.
gt_tc = np.zeros_like(gt_depths)
sim_tc = np.zeros_like(gt_depths)

timesteps = list(range(Nt))
for t in range(0,Nt,2):
    print('Processing Timestep:', t)
    timestep = t
    # Get the depths for that timestep.
    gt_depths, gt_depth_path = land_cover_utils.terrain_water_depth(dem_fp, gt_plan_fp, cell_facepoint_idx_path, facepoint_coord_path,
                                        depth_path, cell_coord_path, timestep, out_fname_prefix='GT', nodata=-999.0, cleanup_rasters=True,
                                                                   resample=resample)
    sim_depths, sim_depth_path = land_cover_utils.terrain_water_depth(dem_fp, sim_best_plan_fp, cell_facepoint_idx_path, facepoint_coord_path,
                                            depth_path, cell_coord_path, timestep, out_fname_prefix='', nodata=-999.0, cleanup_rasters=True,
                                                                     resample=resample)
    # Cells that exceed cutoff depth.
    gt_exceed = gt_depths > depth_cut
    sim_exceed = sim_depths > depth_cut
    
    # Set gt_tc or sim_tc cells to the timestep when the first surpass the depth cut.
    gt_tc_mask = gt_tc > 0 # Already assigned cells.
    sim_tc_mask = sim_tc > 0 # Already assigned cells.
    gt_tc[gt_exceed & ~gt_tc_mask] = t
    sim_tc[sim_exceed & ~sim_tc_mask] = t
    
    print('Completed Timstep:', t, '\n')
# Out:
# Processing Timestep: 0
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_0.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_0.tif
# (1335, 1521)
# Completed Timstep: 0
#
# Processing Timestep: 2
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_2.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_2.tif
# (1335, 1521)
# Completed Timstep: 2
#
# Processing Timestep: 4
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_4.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_4.tif
# (1335, 1521)
# Completed Timstep: 4
#
# Processing Timestep: 6
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_6.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_6.tif
# (1335, 1521)
# Completed Timstep: 6
#
# Processing Timestep: 8
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_8.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_8.tif
# (1335, 1521)
# Completed Timstep: 8
#
# Processing Timestep: 10
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_10.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_10.tif
# (1335, 1521)
# Completed Timstep: 10
#
# Processing Timestep: 12
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_12.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_12.tif
# (1335, 1521)
# Completed Timstep: 12
#
# Processing Timestep: 14
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_14.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_14.tif
# (1335, 1521)
# Completed Timstep: 14
#
# Processing Timestep: 16
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_16.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_16.tif
# (1335, 1521)
# Completed Timstep: 16
#
# Processing Timestep: 18
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_18.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_18.tif
# (1335, 1521)
# Completed Timstep: 18
#
# Processing Timestep: 20
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_20.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_20.tif
# (1335, 1521)
# Completed Timstep: 20
#
# Processing Timestep: 22
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_22.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_22.tif
# (1335, 1521)
# Completed Timstep: 22
#
# Processing Timestep: 24
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_24.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_24.tif
# (1335, 1521)
# Completed Timstep: 24
#
# Processing Timestep: 26
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_26.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_26.tif
# (1335, 1521)
# Completed Timstep: 26
#
# Processing Timestep: 28
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_28.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_28.tif
# (1335, 1521)
# Completed Timstep: 28
#
# Processing Timestep: 30
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_30.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_30.tif
# (1335, 1521)
# Completed Timstep: 30
#
# Processing Timestep: 32
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_32.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_32.tif
# (1335, 1521)
# Completed Timstep: 32
#
# Processing Timestep: 34
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_34.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_34.tif
# (1335, 1521)
# Completed Timstep: 34
#
# Processing Timestep: 36
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_36.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_36.tif
# (1335, 1521)
# Completed Timstep: 36
#
# Processing Timestep: 38
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_38.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_38.tif
# (1335, 1521)
# Completed Timstep: 38
#
# Processing Timestep: 40
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_40.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_40.tif
# (1335, 1521)
# Completed Timstep: 40
#
# Processing Timestep: 42
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_42.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_42.tif
# (1335, 1521)
# Completed Timstep: 42
#
# Processing Timestep: 44
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_44.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_44.tif
# (1335, 1521)
# Completed Timstep: 44
#
# Processing Timestep: 46
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_46.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_46.tif
# (1335, 1521)
# Completed Timstep: 46
#
# Processing Timestep: 48
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_48.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_48.tif
# (1335, 1521)
# Completed Timstep: 48
#
# Processing Timestep: 50
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_50.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_50.tif
# (1335, 1521)
# Completed Timstep: 50
#
# Processing Timestep: 52
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_52.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_52.tif
# (1335, 1521)
# Completed Timstep: 52
#
# Processing Timestep: 54
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_54.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_54.tif
# (1335, 1521)
# Completed Timstep: 54
#
# Processing Timestep: 56
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_56.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_56.tif
# (1335, 1521)
# Completed Timstep: 56
#
# Processing Timestep: 58
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_58.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_58.tif
# (1335, 1521)
# Completed Timstep: 58
#
# Processing Timestep: 60
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_60.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_60.tif
# (1335, 1521)
# Completed Timstep: 60
#
# Processing Timestep: 62
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_62.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_62.tif
# (1335, 1521)
# Completed Timstep: 62
#
# Processing Timestep: 64
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_64.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_64.tif
# (1335, 1521)
# Completed Timstep: 64
#
# Processing Timestep: 66
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_66.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_66.tif
# (1335, 1521)
# Completed Timstep: 66
#
# Processing Timestep: 68
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_68.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_68.tif
# (1335, 1521)
# Completed Timstep: 68
#
# Processing Timestep: 70
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_70.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_70.tif
# (1335, 1521)
# Completed Timstep: 70
#
# Processing Timestep: 72
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_72.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_72.tif
# (1335, 1521)
# Completed Timstep: 72
#
# Processing Timestep: 74
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_74.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_74.tif
# (1335, 1521)
# Completed Timstep: 74
#
# Processing Timestep: 76
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_76.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_76.tif
# (1335, 1521)
# Completed Timstep: 76
#
# Processing Timestep: 78
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_78.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_78.tif
# (1335, 1521)
# Completed Timstep: 78
#
# Processing Timestep: 80
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_80.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_80.tif
# (1335, 1521)
# Completed Timstep: 80
#
# Processing Timestep: 82
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_82.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_82.tif
# (1335, 1521)
# Completed Timstep: 82
#
# Processing Timestep: 84
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_84.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_84.tif
# (1335, 1521)
# Completed Timstep: 84
#
# Processing Timestep: 86
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_86.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_86.tif
# (1335, 1521)
# Completed Timstep: 86
#
# Processing Timestep: 88
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_88.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_88.tif
# (1335, 1521)
# Completed Timstep: 88
#
# Processing Timestep: 90
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_90.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_90.tif
# (1335, 1521)
# Completed Timstep: 90
#
# Processing Timestep: 92
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_92.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_92.tif
# (1335, 1521)
# ...
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_252.tif
# (1335, 1521)
# Completed Timstep: 252
#
# Processing Timestep: 254
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_254.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_254.tif
# (1335, 1521)
# Completed Timstep: 254
#
# Processing Timestep: 256
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_256.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_256.tif
# (1335, 1521)
# Completed Timstep: 256
#
# Processing Timestep: 258
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_258.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_258.tif
# (1335, 1521)
# Completed Timstep: 258
#
# Processing Timestep: 260
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_260.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_260.tif
# (1335, 1521)
# Completed Timstep: 260
#
# Processing Timestep: 262
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_262.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_262.tif
# (1335, 1521)
# Completed Timstep: 262
#
# Processing Timestep: 264
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_264.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_264.tif
# (1335, 1521)
# Completed Timstep: 264
#
# Processing Timestep: 266
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_266.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_266.tif
# (1335, 1521)
# Completed Timstep: 266
#
# Processing Timestep: 268
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_268.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_268.tif
# (1335, 1521)
# Completed Timstep: 268
#
# Processing Timestep: 270
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_270.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_270.tif
# (1335, 1521)
# Completed Timstep: 270
#
# Processing Timestep: 272
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_272.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_272.tif
# (1335, 1521)
# Completed Timstep: 272
#
# Processing Timestep: 274
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_274.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_274.tif
# (1335, 1521)
# Completed Timstep: 274
#
# Processing Timestep: 276
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_276.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_276.tif
# (1335, 1521)
# Completed Timstep: 276
#
# Processing Timestep: 278
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_278.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_278.tif
# (1335, 1521)
# Completed Timstep: 278
#
# Processing Timestep: 280
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_280.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_280.tif
# (1335, 1521)
# Completed Timstep: 280
#
# Processing Timestep: 282
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Orig_GT\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_282.tif
# (1335, 1521)
# C:\Users\ay434\Documents\10_min_Runs\Secchia_flood_2014_30min_Sim\Secchia_Panaro.p23.hdf
# DEM SHAPE (1335, 1521)
# gdal_rasterize -at -l mesh_gjson -a Depth -tr 20.00197238658777 20.014232209737827 -a_nodata -999.0 -te 652093.732276195 4945405.219236948 682516.732276195 4972124.219236948 -ot Float32 -of GTiff C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_gjson.geojson C:\Users\ay434\Documents\rasopt\src\rasopt\Utilities\Geo_Files\mesh_raster_282.tif
# (1335, 1521)
# Completed Timstep: 282

# %%
delta_save_fname = 'delta_30min_1veg_camp0.05.npy'

# %%
# Difference in time to critical depth.
delta_tc = (gt_tc - sim_tc) * dt
print(np.max(delta_tc[delta_tc > 0]))

print(np.sum(delta_tc))

fig, ax = plt.subplots()
ax.hist(delta_tc[delta_tc != 0])

delta_tc_plot = delta_tc.copy()
delta_tc_plot[delta_tc_plot == 0] = np.nan
fig, ax = plt.subplots(figsize=(20,20))
im = ax.imshow(delta_tc_plot)
plt.colorbar(im)

np.save(delta_save_fname, delta_tc)
# Out:
# 125.0
# 233448.0

# %% [markdown]
# ###
